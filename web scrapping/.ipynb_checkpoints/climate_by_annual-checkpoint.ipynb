# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd
import numpy as np

# %%
URL = "https://en.tutiempo.net/climate/ws-{}.html"

# %%
cities = {
    'Toronto': '716240',
    'Vancouver': '718920',
    'Quebec City':'717140',
    'Montreal':'716270',
    'Ottawa':'716280',
    'St John':'718010',
    'Charlottetown':'717060',
    'Halifax':'713950'
}

# %%
def get_df_for_city(city_id, city_name):
    req = requests.get(URL.format(city_id))
    soup = BeautifulSoup(req.content, 'lxml')
    table = soup.findAll('table', {'class': 'medias'})[0]
    table_arr = np.array([[cell.text for cell in row.find_all(["th","td"])] for row in table.find_all("tr")])
    tab_header = table_arr[0]
    tab_data = np.delete(table_arr, (0), axis=0)
    df_data = []
    for row_data in tab_data:
        row = []
        for val in row_data:
            if val == '-':
                row.append(np.nan)
            else:
                row.append(np.float(val))
        df_data.append(row)
    df = pd.DataFrame(columns=tab_header, data = df_data)
    ## Feature cleaning
    df = df[df.Year >= 1990]
    df = df[df.Year < 2020]
    med = df.median()
    df.fillna(value=med, inplace=True)
    df['City'] = city_name
    return df.reset_index(drop=True)

# %%
df = get_df_for_city('713950', 'Toronto')

# %%
df.head(200)
# Out:
#       Year    T    TM   Tm       PP     V     RA     SN    TS     FG   TN  \
# 0   1982.0  6.1  10.8  2.1  1330.65  16.8  154.0   94.0  10.0  185.0  0.0
# 1   1983.0  7.2  11.4  3.7  1330.65  16.9  173.0   78.0   8.0  194.0  0.0
# 2   1984.0  6.9  11.4  3.1  1330.65  15.9  166.0   91.0  11.0  211.0  0.0
# 3   1985.0  5.6  10.1  1.9     0.00  16.4  150.0  101.0   9.0  175.0  0.0
# 4   1986.0  5.7  10.3  1.8     0.00  16.4  181.0   85.0   7.0  212.0  0.0
# 5   1987.0  6.8  12.2  2.3  1330.65  17.5  174.5   93.5  10.0  114.5  0.0
# 6   1993.0  6.8  12.2  2.3  1330.65  17.5  174.5   93.5  10.0  114.5  0.0
# 7   1994.0  6.4  11.2  2.5     0.00  15.4  168.0   92.0  12.0  187.0  0.0
# 8   1995.0  6.5  11.0  2.7     0.00  13.9  170.0  120.0  10.0  185.0  0.0
# 9   1996.0  6.4  10.6  2.7  1330.65  15.0  198.0   98.0  13.0  164.0  0.0
# 10  1997.0  5.8  10.4  1.9     0.00  15.0  161.0  124.0  14.0  114.0  0.0
# 11  1998.0  7.6  11.9  4.1     0.00  16.2  181.0   85.0  13.0  115.0  0.0
# 12  1999.0  8.3  14.0  3.4  1330.65  17.2  181.0   87.0  12.0  115.0  0.0
# 13  2000.0  7.1  12.7  2.5  1329.36  17.1  184.0   94.0  12.0  120.0  0.0
# 14  2001.0  7.4  13.0  2.5  1048.61  15.6  138.0  116.0  10.0  116.0  0.0
# 15  2002.0  6.8  12.2  2.3  1330.65  17.5  165.0  112.0  14.0  117.0  0.0
# 16  2003.0  6.9  12.5  2.0  1268.42  15.8  152.0  105.0   6.0   79.0  0.0
# 17  2004.0  6.1  11.7  1.4  1248.61  17.9  170.0  100.0   7.0  118.0  0.0
# 18  2005.0  6.8  12.2  2.3  1330.65  17.5  174.5   93.5  10.0  114.5  0.0
# 19  2006.0  7.5  13.2  2.3  1330.65  17.6  178.0   69.0  11.0  118.0  0.0
# 20  2007.0  5.7  12.1  0.3  1330.65  18.3  170.0   88.0  19.0   72.0  0.0
# 21  2008.0  6.4  12.7  0.5  1680.38  17.9  194.0   87.0  16.0   87.0  0.0
# 22  2009.0  6.0  12.2  0.1  1509.76  18.0  179.0   93.0   8.0   74.0  0.0
# 23  2010.0  7.7  13.4  2.7  1320.45  18.2  176.0   79.0   9.0   77.0  0.0
# 24  2011.0  6.8  12.9  1.3  1704.24  18.1  181.0   86.0  11.0   88.0  0.0
# 25  2012.0  7.9  13.8  2.5  1769.04  17.5  177.0   75.0  10.0   85.0  0.0
# 26  2013.0  6.5  11.9  1.7  1526.97  18.2  176.0   98.0   9.0  105.0  0.0
# 27  2014.0  7.1  12.7  2.3  1622.51  18.4  196.0   98.0   6.0  107.0  0.0
# 28  2015.0  6.5  12.2  1.7  1640.54  18.2  162.0  107.0   9.0   95.0  0.0
# 29  2016.0  7.4  13.0  2.9  1673.62  18.1  180.0   89.0   7.0  102.0  0.0
# 30  2017.0  7.5  13.0  2.9  1671.81  18.2  158.0  102.0   7.0  107.0  0.0
# 31  2018.0  7.4  13.0  2.7  1661.61  19.0  170.0   98.0   8.0  107.0  0.0
# 32  2019.0  6.7  12.4  2.1  1461.52  18.8  182.0   93.0  15.0   99.0  0.0
#
#      GR     City
# 0   0.0  Toronto
# 1   1.0  Toronto
# 2   0.0  Toronto
# 3   1.0  Toronto
# 4   0.0  Toronto
# 5   0.5  Toronto
# 6   0.5  Toronto
# 7   0.0  Toronto
# 8   1.0  Toronto
# 9   0.0  Toronto
# 10  1.0  Toronto
# 11  0.0  Toronto
# 12  0.0  Toronto
# 13  1.0  Toronto
# 14  0.0  Toronto
# 15  1.0  Toronto
# 16  1.0  Toronto
# 17  0.0  Toronto
# 18  0.5  Toronto
# 19  2.0  Toronto
# 20  1.0  Toronto
# 21  2.0  Toronto
# 22  0.0  Toronto
# 23  2.0  Toronto
# 24  1.0  Toronto
# 25  0.0  Toronto
# 26  0.0  Toronto
# 27  1.0  Toronto
# 28  0.0  Toronto
# 29  1.0  Toronto
# 30  1.0  Toronto
# 31  0.0  Toronto
# 32  0.0  Toronto

# %%
dfs = []
for key, val in cities.items():
    dfs.append(get_df_for_city(val, key))

# %%
fdf = pd.concat(dfs)

# %%
fdf.to_csv('final_df.csv', index=False)

# %%
fdf.head(200)
# Out:
#       Year    T    TM   Tm       PP     V     RA     SN    TS     FG   TN  \
# 0   1982.0  7.2  13.3  1.2   923.73  13.7  143.0   92.0  22.0  162.0  0.0
# 1   1983.0  8.1  13.9  2.4   836.67  13.4  162.0   86.0  32.0  158.0  0.0
# 2   1984.0  7.6  13.5  1.8   843.99  12.8  153.0   77.0  29.0  165.0  0.0
# 3   1985.0  7.5  13.5  2.0   986.20  16.3  152.0   99.0  28.0  149.0  0.0
# 4   1986.0  7.8  13.6  2.1  1091.85  14.1  154.0   76.0  33.0  166.0  0.0
# ..     ...  ...   ...  ...      ...   ...    ...    ...   ...    ...  ...
# 5   1987.0  4.5   9.7  0.2  1431.45  22.5  203.0  131.0   4.0  201.0  0.0
# 6   1988.0  5.0  10.5  0.7  1517.42  24.6  223.0  132.0   4.0  225.0  0.0
# 7   1989.0  4.4  10.3 -0.4  1233.08  24.9  196.0  133.0   2.0  197.0  0.0
# 8   1990.0  4.7  10.3 -0.1  1517.07  23.1  205.0  129.0   4.0  214.0  0.0
# 9   1991.0  3.9   9.4 -0.9  1394.75  20.3  213.0  127.0   5.0  231.0  0.0
#
#      GR     City
# 0   1.0  Toronto
# 1   4.0  Toronto
# 2   1.0  Toronto
# 3   3.0  Toronto
# 4   2.0  Toronto
# ..  ...      ...
# 5   0.0  St John
# 6   0.0  St John
# 7   0.0  St John
# 8   1.0  St John
# 9   2.0  St John
#
# [200 rows x 13 columns]
